# %%
import pandas as pd

# %%
# Create an empty pandas Series

pd.Series()
# Out:
# Series([], dtype: object)

# %%
# Given the X python list convert it to an Y pandas Series

x = ['A' , 'B' , 'C' , 'D']

y = pd.Series(x)

# %%
# Given the X pandas Series, name it 'My letters'

x = pd.Series(['A' , 'B' , 'C'])

x.name = 'My Letters'
x
# Out:
# 0    A
# 1    B
# 2    C
# Name: My Letters, dtype: object

# %%
# Given the X pandas Series, show its values

x.values
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
# SERIES INDEXATION

# %%
# Assign index names to the given X pandas Series

index = ['Letter_1' , 'Letter_2' , 'Letter_3'] 

x.index = index
x
# Out:
# Letter_1    A
# Letter_2    B
# Letter_3    C
# Name: My Letters, dtype: object

# %%
# Given the X pandas Series, show its first element

x[0]  # by position
x.iloc[0] # by position
x.loc['Letter_1'] # by index
# Out:
# 'A'

# %%
# Given the X pandas Series, show its last element

x[-1]
# x.iloc[-1]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1068\3207615784.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x[-1]
# 'C'

# %%
# Given the X pandas Series, show all middle elements

x[1:-1]
# Out:
# Letter_2    B
# Name: My Letters, dtype: object

# %%
# Given the X pandas Series, show the elements in reverse position

x[::-1]
# Out:
# Letter_3    C
# Letter_2    B
# Letter_1    A
# Name: My Letters, dtype: object

# %%
# Given the X pandas Series, show the first and last elements

x.iloc[[0 , -1]]
# Out:
# Letter_1    A
# Letter_3    C
# Name: My Letters, dtype: object

# %%
# # SERIES MANIPULATION

# Convert the given integer pandas Series to float


x = pd.Series([ 0 , 1 , 2 , 3] , dtype = 'float64' , index = ['Num_1' , 'Num_2' , 'Num_3' , 'Num_4'])
x
# Out:
# Num_1    0.0
# Num_2    1.0
# Num_3    2.0
# Num_4    3.0
# dtype: float64

# %%
# Reverse the given pandas Series (first element becomes last)

x[:: -1]
# Out:
# Num_4    3.0
# Num_3    2.0
# Num_2    1.0
# Num_1    0.0
# dtype: float64

# %%
# Order (sort) the given pandas Series

x.sort_values()
# Out:
# Num_1    0.0
# Num_2    1.0
# Num_3    2.0
# Num_4    3.0
# dtype: float64

# %%
# Given the X pandas Series, set the third element equal to 10

x['Num_4'] = 10
# Out:
# Num_1     0.0
# Num_2     1.0
# Num_3     2.0
# Num_4    10.0
# dtype: float64

# %%
# Given the X pandas Series, change all the middle elements to 0

x[1:-1]= 0
x
# Out:
# Num_1     0.0
# Num_2     0.0
# Num_3     0.0
# Num_4    10.0
# dtype: float64
