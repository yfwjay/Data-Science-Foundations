# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# We will read one of our data sets. Most likely the social media one. It has categorical vraibles.

df = pd.read_csv(r"C:\Users\HP\Desktop\Data-Science-Foundations\datasets\social_media_engagement_dataset.csv")
df
# Out:
#        platform post_type  post_length   views  likes  comments  shares  \
# 0      Facebook      Text           62   91660   2968       276     346
# 1     Instagram     Video          104  113115   4164       632     406
# 2      Facebook     Video           46   36043   3125       188     100
# 3      Facebook     Image           39  124886   5970       948     578
# 4     Instagram     Video           42   82831   8212      1104     334
# ...         ...       ...          ...     ...    ...       ...     ...
# 9995   Facebook     Image           65   42330   1436       158     122
# 9996  Instagram      Text          119  254309  12274      2226    1089
# 9997    Twitter     Image           17   48415   4126       503     581
# 9998    Twitter     Video           16   63006   5504       529     499
# 9999   Facebook     Image           33  183199  17318      1292     971
#
#       engagement_rate
# 0            0.039166
# 1            0.045989
# 2            0.094692
# ...

# %%
# since it has alot of rows we will use 100. So we select randomly 100 rows and use seed so that we make sure each time we run the code we always get the same rows

sample_df = df.sample(n = 100 , random_state= 42)
sample_df
# Out:
#        platform post_type  post_length   views  likes  comments  shares  \
# 6252    Twitter     Video            5  191448  10948      1243    1327
# 4684  Instagram      Text           30   49690   2629       520     186
# 1731   Facebook     Image           85   50165   2209       299     289
# 4742    Twitter     Video           21   41007   3924       742     136
# 4521   Facebook     Video           92   19035   1183       231      90
# ...         ...       ...          ...     ...    ...       ...     ...
# 3787   Facebook     Video           25  172546   4247       398     405
# 9189  Instagram      Text          102  289127   5804       848     549
# 7825    Twitter      Text          100   33914   2761       262     138
# 7539   Facebook      Text           56  109373   3795       481     455
# 7231   Facebook     Image          105   14706    361        51      43
#
#       engagement_rate
# 6252         0.070609
# 4684         0.067116
# 1731         0.055756
# ...

# %%
# We use the info function to know which columns have categorical variables

sample_df.info()

# From the dtypes only column platform and pst_type can have categorical variables as they are of dtype object.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 6252 to 7231
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   platform         100 non-null    object
#  1   post_type        100 non-null    object
#  2   post_length      100 non-null    int64
#  3   views            100 non-null    int64
#  4   likes            100 non-null    int64
#  5   comments         100 non-null    int64
#  6   shares           100 non-null    int64
#  7   engagement_rate  100 non-null    float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 7.0+ KB

# %%
# 1.COUNT PLOT

# %%
# We plot one of our columns

fig , axes = plt.subplots(figsize = (12 , 6))

c = sns.catplot(x = 'platform' , data = sample_df , kind = 'count' , hue = 'platform')

c.fig.suptitle("A Count Plot showing the different Paltforms Present" , fontsize = 12)

# Position our title to a nice position to prevent it from overlapping from the plot

c.fig.subplots_adjust(top = 0.9)
